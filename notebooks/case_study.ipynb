# %% [markdown]
# # BINA Case Study: Auswirkungen von Niederschlag auf Schweizer Bahnverkehr

# %% [markdown]
# **Case Study**
#
# **Modul: Business Intelligence & Analytics**
#
#
# Autor*innen: Shannon Breitenmoser, Severin Clauss, Alexander Bürki, Marija Cirkovic, Roxana Gnes
#
# Datum: 18. Mai 2026

# %% [markdown]
# # 1. Einleitung
#
# Ein zuverlässiger und pünktlicher öffentlicher Verkehr stellt einen zentralen Bestandteil der Mobilität in der Schweiz dar. Insbesondere der Bahnverkehr spielt dabei eine bedeutende Rolle, da täglich zahlreiche Menschen für berufliche, schulische oder private Zwecke auf die Züge der Schweizerischen Bundesbahnen (SBB) angewiesen sind. Die SBB gelten als eines der pünktlichsten Bahnunternehmen und leisten damit einen wichtigen Beitrag zur Funktionsfähigkeit des Schweizer Verkehrssystems.
#
# Trotz der hohen Zuverlässigkeit des Bahnnetzes kann die Fahrplanstabilität durch verschiedene Faktoren beeinflusst werden. Neben betrieblichen Ursachen wie technischen Störungen, Bauarbeiten oder einer hohen Netzauslastung können auch äussere Einflüsse eine Rolle spielen. Dazu zählen unter anderem meteorologische Bedingungen, die potenziell Auswirkungen auf den Bahnbetrieb haben können.
#
# Vor diesem Hintergrund beschäftigt sich dieses Projekt mit dem Thema Einfluss von Niederschlag auf die Fahrplanstabilität der Züge der SBB.

# %% [markdown]
# ## 1.1 Zielsetzung
#
# Ziel dieser Arbeit ist es, einen möglichen Zusammenhang zwischen Niederschlag und der Fahrplanstabilität der Züge der SBB zu untersuchen. Dabei soll analysiert werden, ob und in welchem Ausmass Niederschlagsereignisse mit Veränderungen in der Pünktlichkeit und Ausfällen des Bahnverkehrs in Verbindung stehen.
#
# Zu diesem Zweck werden Wetterdaten zu Niederschlagsmengen mit verfügbaren Abfahrts- und Ankunftszeiten der SBB kombiniert und statistisch ausgewertet. Durch die Analyse dieser Daten soll geprüft werden, ob sich Hinweise auf einen Zusammenhang zwischen der Intensität von Niederschlag und möglichen Fahrplanabweichungen erkennen lassen.
#
# Die Ergebnisse der Untersuchung sollen dazu beitragen, ein besseres Verständnis für mögliche wetterbedingte Einflüsse auf die Stabilität des Bahnverkehrs zu gewinnen.

# %% [markdown]
# ## 1.2 Vorgehen
#
# Um nach der Einleitung und Zielsetzung die Fragestellungen im nächsten Kapitel zu beantworten, wird ein datengetriebener Analyseansatz verfolgt. Dieser orientiert sich an den Grundprinzipien der datengestützten Entscheidungsfindung (Data-Driven Decision Making). Den Prozess gliedern wir in mehrere aufeinanderfolgende Schritte.
#
# 1.   Datenbeschaffung: Zunächst werden die Daten beschafft. Die IST-Daten des Bahnverkehrs stammen aus dem Open-Data-Portal des öffentlichen Verkehrs, während die Niederschlagsdaten von MeteoSchweiz bezogen werden. Wir haben uns für diese Analyse bewusst für die Jahre 2022 bis 2025 sowie die Regionen Zürich, Bern und Basel entschieden, da sie eine gute Grundlage für unsere Untersuchungen bieten. Die beiden Datensätze dienen als Basis für alle weiteren Analysen.
#
# 2.   Datenaufbereitung: In einem zweiten Schritt erfolgt dann die Aufbereitung und Bereinigung der Daten. Hierzu zählt das Eliminieren unvollständiger oder falscher Einträge, das Vereinheitlichen von Zeitformaten und das Herausfiltern relevanter Variablen, also die Datentransformation. Die Fahrplandaten werden vor allem genutzt, um die effektiven Verspätungen in Minuten zu ermitteln, indem die geplanten und tatsächlichen Ankunfts- beziehungsweise Abfahrtszeiten miteinander gegenübergestellt werden.
#
# 3.   Datenverknüpfung: Im dritten Schritt werden die Datensätze miteinander verknüpft. Hierbei werden die Daten des Fahrplans mit den Wetterdaten kombiniert. Fahrten werden vorrangig anhand ihres zeitlichen und örtlichen Bezuges zugeordnet. Hierfür werden den entsprechenden Bahnhöfen oder Streckenabschnitten die nächstgelegenen Wetterstationen zugewiesen. Im Anschluss daran werden die Niederschlagswerte in geeigneten Zeitintervallen, wie etwa stündlich oder täglich, den entsprechenden Fahrten zugeordnet. Hierdurch wird ein kombinierter Datensatz generiert, der betriebliche und meteorologische Informationen umfasst.
#
# 4.   Datenanalyse: Im vierten Schritt wird dann eine explorative Datenanalyse vorgenommen. Die Absicht besteht darin, allfällige Muster, Auffälligkeiten und potenzielle Verbindungen zwischen Niederschlag und Verspätungen zu erkennen. Dies geschieht unter anderem durch statistische Kennzahlen, Visualisierungen und den Vergleich von Tagen mit und ohne Niederschlag.
#
# 5.   Datenauswertung: Im fünften Schritt widmen wir uns der statistisch‑analytischen Auswertung. Hierzu werden geeignete Methoden verwendet, um den Zusammenhang zwischen Niederschlagsmenge und Verspätungen quantitativ zu analysieren. Darunter fallen unter anderem Korrelationsanalysen und die Analyse von Schwellenwerten, ab denen signifikante Veränderungen in der Pünktlichkeit zu beobachten sind. Um ein differenzierteres Bild zu erhalten, können bei Bedarf weitere Einflussfaktoren wie Temperatur oder Zugtyp in die Analyse aufgenommen werden.
#
# 6.   Interpretation und Bewertung: Im letzten Schritt erfolgt die Interpretation und Bewertung der Ergebnisse. Die gewonnenen Erkenntnisse werden im Hinblick auf die Fragestellung erörtert und kritisch eingeordnet. Im Fokus steht vor allem die Frage, ob ein statistisch bedeutsamer Zusammenhang zwischen Niederschlag und Fahrplanabweichungen besteht und welche praktischen Konsequenzen sich daraus für den Bahnbetrieb ergeben.
#
# 7. Erstellen einer interaktiven Applikation zur berechneten vorhersage der Verspätung aufgrund des Niederschlags.
#
# Mit diesem klaren Vorgehen können wir nachvollziehbar und fundiert analysieren, ob und wie sich Niederschlag auf die Pünktlichkeit der SBB auswirkt und somit die nachfolgenden Fragestellungen klar beantworten.

# %% [markdown]
# ## 1.3 Fragestellungen
#
# Basierend auf dem Titel dieser Arbeit ergeben sich diverse Fragestellungen die für eine Analyse interessant sein können. Hauptfrage ist hierbei die Bestimmung eines Zusammenhangs zwischen Niederschlag und Verspätungen:
#
# *   Ist ein Zusammenhang zwischen der Niederschlagsmenge auf einer Bahnstrecke und einer Verspätung eines Zuges erkennbar?
#
# Vertiefend dazu lassen sich Nebenfragen definieren:
#
# *   Ist ein Schwellenwert für den Niederschlagswert erkennbar ab dem die Pünktlichkeit signifikant sinkt?
# *   Gibt es besonders anfällige Verbindungen?
# *   Sind bestimmte Zugtypen anfälliger für Verzögerungen durch starken Niederschlag?

# %% [markdown]
# # 2. Datengrundlagen
#
# Die vorliegende Analyse stützt sich auf zwei zentrale Datenquellen, welche die Grundlage für die Untersuchung des Zusammenhangs zwischen Niederschlagsereignissen und der Fahrplanstabilität der Schweizerischen Bundesbahnen (SBB) bilden. Um die Korrelation zu untersuchen, werden die täglichen Daten der Jahre 2022 bis 2025 verglichen.
#
# Diese Analyse stützt sich auf diese beiden Jahre, da diese im Archiv von Open Transport Data Swiss bereitgestellt sind und die täglichen Daten vorliegen.

# %% [markdown]
# ## 2.1 Ist-Daten des Schweizer Bahnverkehrs
#
# Die Fahrplandaten stammen aus dem Open-Data-Portal des öffentlichen Verkehrs (data.opentransportdata.swiss). Der dort bereitgestellte Datensatz «Ist-Daten Archiv» enthält tagesaktuelle Informationen über alle Fahrten im schweizerischen öffentlichen Verkehr. Für jede Fahrt werden unter anderem folgende Attribute erfasst: die geplante und tatsächliche Ankunfts- sowie Abfahrtszeit an den jeweiligen Haltestellen, die Linien- und Fahrtbezeichnung sowie allfällige Ausfälle oder Streckenänderungen. Aus diesen Rohdaten lässt sich die Verspätung einzelner Züge in Minuten ableiten, wodurch eine quantitative Bewertung der Pünktlichkeit auf Fahrt-, Strecken- und Tagesebene möglich wird.

# %% [markdown]
# Nachfolgend werden  die, für die Auswertung relevanten Felder der CSV-Dateien im Detail beschrieben:
#
# | Feldname             | Typ                     | Beschreibung                                                                                                                                                                                                 | Beispiel                          |
# |----------------------|-------------------------|--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|-----------------------------------|
# | BETRIEBSTAG          | DD.MM.YYYY              | Dies ist der Betriebstag, an welchem die Fahrt stattgefunden hat.                                                                                                                                            | 22.05.2024                        |
# | FAHR_BEZEICHNER      | String                  | Entspricht der FahrtID: Nahverkehr:[UIC-Ländercode]:[GO-Nummer]:[Fahrt-Referenz] Bahnverkehr:[UIC-Ländercode]:[GO-Nummer]:[VM-Nummer]:[Erweiterte Referenz]                                                  | ch:1:sjyid:100001:17128-001       |
# | BETREIBER_NAME       | String                  | Hergeleitet aus den Angaben BETREIBER_ID über die Stammdaten des Transportunternehmens                                                                                                                       | Schweizerische Bundesbahnen SBB   |
# | PRODUKT_ID           | Enum                    | Angabe der Verkehrsmittel-Kategorie (z.B. Schiff)                                                                                                                                                             | Zug                               |
# | FAELLT_AUS_TF        | Boolean                 | true/false (wenn null=false). Ist auf true gesetzt, wenn die Fahrt ausfällt.                                                                                                                                  | false                             |
# | HALTESTELLEN_NAME    | String                  | Die textuelle Repräsentation der Haltestelle.                                                                                                                                                                  | Zürich HB                         |
# | ANKUNFTSZEIT         | DD.MM.YYYY HH24:MI      | Die Soll-Ankunftszeit an der Haltestelle gerundet auf Minuten.                                                                                                                                                | 12.10.2016 05:40                  |
# | AN_PROGNOSE          | DD.MM.YYYY HH24:MI:SS   | Die Prognose der Ankunft ohne Rundung. Achtung: Es kann sein, dass eine Transportunternehmung die Rundung schon vorgenommen hat und daher Sekunden fehlen.                                                   | 12.10.2016 05:41:32               |
# | AN_PROGNOSE_STATUS   | Enum                    | Mögliche Werte: UNBEKANNT, PROGNOSE, GESCHAETZT, REAL                                                                                                                                                          | REAL                              |
# | ABFAHRTSZEIT         | DD.MM.YYYY HH24:MI      | Die Soll-Abfahrtszeit an der Haltestelle gerundet auf Minuten.                                                                                                                                                | 12.10.2016 05:40                  |
# | AB_PROGNOSE          | DD.MM.YYYY HH24:MI:SS   | Die Prognose der Abfahrt ohne Rundung. Achtung: Sekunden können fehlen.                                                                                                                                       | 12.10.2016 05:41:32               |
# | AB_PROGNOSE_STATUS   | Enum                    | Mögliche Werte: UNBEKANNT, PROGNOSE, GESCHAETZT, REAL                                                                                                                                                          | REAL                              |
#
# Tabelle 1: Relevante Datenfelder des öffentlichen Verkehrs (opentransportdata.swiss (o. J.))

# %% [markdown]
# ## 2.2 Niederschlagsdaten von MeteoSchweiz
#
# Die meteorologischen Daten werden vom nationalen Wetter- und Klimadienst MeteoSchweiz bezogen. Konkret werden die Daten der automatischen Niederschlagsstationen verwendet, die schweizweit rund 140 Standorte umfassen. Für diese Analyse werden die Stationen der Regionen Zürich, Bern und Basel berücksichtigt. Diese Stationen liefern kontinuierliche Niederschlagsmessungen im Zehnminutenraster, wobei jeweils die Niederschlagssumme der vorangegangenen zehn Minuten erfasst wird. Die vollautomatische Messung in Echtzeit ermöglicht eine zeitlich präzise Zuordnung von Wetterereignissen zu den entsprechenden Fahrten. Die Daten sind über das Open-Data-Portal von MeteoSchweiz frei zugänglich MeteoSwiss (o. J.).
#
# In der folgenden Tabelle 2 sind die benötigten Felder der CSV-Dateien kurz beschrieben:
#
# | Feldname           | Typ        | Beschreibung                                      | Beispiel          |
# |--------------------|------------|--------------------------------------------------|-------------------|
# | station_abbr       | String     | Stationskürzel der Messstation                   | BER               |
# | timestamp          | Timestamp  | Zeitstempel der Messung (Datum + Uhrzeit)       | 01.01.2020 00:00  |
# | rre150z0           | Float      | Niederschlagsmenge (z. B. in mm, Intervallwert) | 0.2               |
#
# Tabelle 2: Relevante Variablen der Wetterdaten (MeteoSwiss (o. J.))

# %% [markdown]
# # 3. Datenanalyse
#
# Im folgenden Kapitel beschreiben die Autor*innen ihr Vorgehen beim Laden, Bereinigen und Analysieren der Daten. Zur Generierung der benötigten Befehle sowie zur Durchführung der Auswertungen wurde Claude AI eingesetzt.

# %% [markdown]
# ## 3.1 Setup
#
#
# Alle erforderlichen Bibliotheken werden nachfolgend geladen und es wird eine Verbindung zur Produktionsdatenbank hergestellt.
# Die Zugangsdaten werden aus `.env.prod` eingelesen – niemals fest im Code hinterlegt.
# Zur Überprüfung wird eine Zeilenzahl-Kontrolle ausgegeben, um sicherzustellen, dass die Datenbank befüllt ist, bevor mit der Analyse begonnen wird.

# %%
import json
import os
from datetime import datetime
from pathlib import Path

import joblib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from dotenv import load_dotenv
from scipy import stats
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sqlalchemy import create_engine, text

# Load production DB credentials — never falls back to hardcoded values
load_dotenv('.env.prod')

db_host = os.getenv('DB_HOST')
db_port = os.getenv('DB_PORT')
db_user = os.getenv('DB_USER')
db_password = os.getenv('DB_PASSWORD')
db_name = os.getenv('DB_NAME')

missing = [k for k, v in {
    'DB_HOST': db_host, 'DB_PORT': db_port, 'DB_USER': db_user,
    'DB_PASSWORD': db_password, 'DB_NAME': db_name,
}.items() if not v]
if missing:
    raise ValueError(f'Missing required variables in .env.prod: {missing}')

# Style — consistent across all charts
sns.set_theme(style='darkgrid')
STATION_COLORS = {
    'Zürich HB': '#1f77b4',   # blue
    'Basel SBB': '#d62728',   # red
    'Bern':      '#2ca02c',   # green
}

engine = create_engine(
    f'postgresql://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}'
)
print(f'Connected to {db_name} on {db_host}:{db_port}')

# %%
# Sanity check — confirm the database is populated before proceeding
with engine.connect() as conn:
    counts = conn.execute(text("""
        SELECT 'train_connections'  AS tbl, COUNT(*) AS n FROM train_connections
        UNION ALL
        SELECT 'precipitation_10min',       COUNT(*)      FROM precipitation_10min
        UNION ALL
        SELECT 'processing_log',            COUNT(*)      FROM processing_log
    """)).fetchall()

print('Row counts:')
for tbl, n in counts:
    print(f'  {tbl:<25} {n:>10,}')

# %% [markdown]
# ## 3.2 Datenvalidierung
#
# Der Datensatz ist vollständig und für die Analyse geeignet — 4.100.349 Verbindungen über 45 Monate hinweg mit 100 % Niederschlagsabdeckung und keinen fehlenden Werten in den Schlüsselspalten.
# Das Schweizer Bahnnetz weist eine mediane Ankunftsverspätung von nur 0,35 Minuten auf.

# %% [markdown]
# Bevor Schlussfolgerungen gezogen werden, wird überprüft, ob der Datensatz vollständig und korrekt strukturiert ist.
# Dieser Abschnitt prüft fehlende Werte, untersucht die Verteilungen der beiden zentralen Variablen (`arrival_delay_min` und `median_precip_mm`), und bestätigt, welche Monate erfolgreich geladen wurden.
# Etwaige hier festgestellte Probleme werden dokumentiert und in späteren Abschnitten als Einschränkungen berücksichtigt.

# %% [markdown]
# ## 3.3 Analyseansicht laden
# Alle nachfolgenden Analysen verwenden die `analysis` Ansicht, die `train_connections` mit `precipitation_10min` verknüpft und abgeleitete Spalten   (`precip_category`,
# `day_of_week`, `month`). Durch das einmalige Laden an dieser Stelle werden wiederholte Datenbankabfragen vermieden.

# %%
df = pd.read_sql('SELECT * FROM analysis', engine)

# Derive year_month (YYYY-MM) from betriebstag for monthly grouping.
# The analysis view does not expose source_month directly.
df['year_month'] = pd.to_datetime(df['betriebstag']).dt.to_period('M').astype(str)

print(f'Loaded {len(df):,} records from analysis view')
print(f'Columns: {list(df.columns)}')
df.head()
df.tail()

# %% [markdown]
# ### NULL-Prüfung in kritischen Feldern

# %% [markdown]
# Fehlende Werte in `arrival_delay_min` würden alle statistischen Ergebnisse unbemerkt verzerren.
# Fehlende Werte in `median_precip_mm` reduzieren die nutzbare Stichprobengrösse für Korrelationen und Modellierungen.
# Beide Aspekte werden hier quantifiziert, damit die Datenqualitätsbeschränkungen von Anfang an transparent sind.

# %%
critical_cols = ['arrival_delay_min', 'median_precip_mm', 'trip_duration_min']
null_summary = pd.DataFrame({
    'column':     critical_cols,
    'null_count': [df[c].isna().sum() for c in critical_cols],
    'total':      len(df),
})
null_summary['null_pct'] = (null_summary['null_count'] / null_summary['total'] * 100).round(2)
null_summary

# %% [markdown]
# ### Verteilung der Ankunftsverspätungen

# %% [markdown]
# Wir stellen die vollständige Verteilung der Ankunftsverspätungen dar, ohne Ausreisser zu entfernen.
# Extreme Verspätungen (> 60 Minuten) sind valide betriebliche Ereignisse — etwa ausgefallene Verbindungen, grössere Störungen oder Infrastrukturprobleme — und müssen im Datensatz enthalten bleiben.
# Eine Entfernung dieser Werte würde die wahrgenommene Pünktlichkeit des Netzes künstlich verbessern.

# %%
delay = df['arrival_delay_min'].dropna()

fig, (ax_hist, ax_box) = plt.subplots(1, 2, figsize=(14, 5),
                                        gridspec_kw={'width_ratios': [3, 1]})

# Left: histogram
sns.histplot(delay, bins=120, color='steelblue', edgecolor=None, ax=ax_hist)
ax_hist.set_title('Arrival Delay Distribution (Full Range)', fontsize=13)
ax_hist.set_xlabel('Arrival Delay (minutes)')
ax_hist.set_ylabel('Number of Train Connections')

# Right: boxplot
ax_box.boxplot(delay, vert=True, patch_artist=True,
               boxprops=dict(facecolor='steelblue', alpha=0.6),
               medianprops=dict(color='black', linewidth=2),
               flierprops=dict(marker='.', alpha=0.2, markersize=3))
ax_box.set_title('Boxplot', fontsize=13)
ax_box.set_ylabel('Arrival Delay (minutes)')
ax_box.set_xticks([])

plt.suptitle('Arrival Delay — Histogram and Boxplot', fontsize=14, y=1.01)
plt.tight_layout()
plt.show()

delay_mean   = delay.mean()
delay_median = delay.median()
delay_p95    = delay.quantile(0.95)
outlier_n    = (delay > 60).sum()
outlier_pct  = outlier_n / len(delay) * 100

print(f'Mean delay:          {delay_mean:.2f} min')
print(f'Median delay:        {delay_median:.2f} min')
print(f'95th percentile:     {delay_p95:.2f} min')
print(f'Outliers (> 60 min): {outlier_n:,} ({outlier_pct:.2f}% of total)')

# %% [markdown]
# Die Verteilung der Ankunftsverspätungen ist deutlich rechtsschief, was mit einem insgesamt sehr pünktlichen Netzwerk konsistent ist.
#
# Zentrale Kennzahlen aus dem geladenen Datensatz:

# %%
print(f'Dataset: {len(df):,} connections across {df["year_month"].nunique()} months')
print(f'Mean delay:          {delay_mean:.2f} min')
print(f'Median delay:        {delay_median:.2f} min')
print(f'95th percentile:     {delay_p95:.2f} min')
print(f'Outliers (> 60 min): {outlier_n:,} ({outlier_pct:.2f}% of total)')
print()
print('Outliers above 60 minutes are retained — they represent valid operational events.')

# %% [markdown]
# ### Verteilung und Abdeckung der Niederschläge

# %% [markdown]
# Niederschlag ist naturgemäss rechtsschief verteilt: Die meisten 10-Minuten-Intervalle sind trocken, und nur ein kleiner Anteil weist messbaren Regen auf.
#
# Die Abdeckung (Prozentsatz der Verbindungen mit einem nicht-NULL-Wert in `median_precip_mm`) bestimmt, wie viel des Datensatzes tatsächlich für die wetterbasierte Analyse nutzbar ist. Eine geringe Abdeckung wäre eine wesentliche Einschränkung für die Aussagekraft der Analyse.

# %%
precip = df['median_precip_mm'].dropna()
coverage_pct = len(precip) / len(df) * 100

fig, (ax_hist, ax_box) = plt.subplots(1, 2, figsize=(14, 5),
                                        gridspec_kw={'width_ratios': [3, 1]})

# Left: histogram
sns.histplot(precip, bins=80, color='teal', edgecolor=None, ax=ax_hist)
ax_hist.set_title('Median Precipitation Distribution (Non-NULL)', fontsize=13)
ax_hist.set_xlabel('Median Precipitation over Trip Window (mm)')
ax_hist.set_ylabel('Number of Train Connections')

# Right: boxplot
ax_box.boxplot(precip, vert=True, patch_artist=True,
               boxprops=dict(facecolor='teal', alpha=0.6),
               medianprops=dict(color='black', linewidth=2),
               flierprops=dict(marker='.', alpha=0.2, markersize=3))
ax_box.set_title('Boxplot', fontsize=13)
ax_box.set_ylabel('Median Precipitation (mm)')
ax_box.set_xticks([])

plt.suptitle('Precipitation — Histogram and Boxplot', fontsize=14, y=1.01)
plt.tight_layout()
plt.show()

print(f'Coverage: {coverage_pct:.1f}% of connections have non-null precipitation')
print(f'  ({len(precip):,} of {len(df):,} records usable for weather analysis)')
print(f'\nPrecipitation stats (non-null only):')
print(precip.describe().round(3))

# %% [markdown]
# Die Niederschlagsabdeckung beträgt **100 %** — jede Verbindung im Datensatz verfügt über einen nicht fehlenden Wert in `median_precip_mm`. Dies ist das bestmögliche Ergebnis: Die MeteoSwiss-Daten weisen keine Sensorlücken auf, die die Analyse beeinträchtigen würden.
#
# Die Verteilung ist stark bei null konzentriert: Mehr als die Hälfte aller Reisezeitfenster ist vollständig trocken (Median = 0,000 mm), was für das mitteleuropäische Klima erwartbar ist.
#
# Diese starke Unausgewogenheit zwischen trockenen und regenreichen Fahrten bedeutet, dass die Korrelationsanalyse hauptsächlich durch eine vergleichsweise kleine Anzahl von Beobachtungen mit Niederschlag geprägt wird.

# %% [markdown]
# ### Vollständigkeit des Zeitraums

# %% [markdown]
# Wir überprüfen, welche Monate erfolgreich geladen wurden, indem wir das `processing_log`
# abfragen und die Ergebnisse mit den tatsächlichen Einträgen in `train_connections` abgleichen. Lücken könnten durch fehlgeschlagene Downloads, Netzwerkunterbrechungen während der Datenerhebung oder noch nicht durch die VM verarbeitete Monate entstehen.

# %%
loaded_months = pd.read_sql("""
    SELECT period, status, rows_inserted, run_at
    FROM   processing_log
    WHERE  run_type = 'sbb' AND status = 'success'
    ORDER  BY period
""", engine)

months_by_station = pd.read_sql("""
    SELECT destination_station, source_month,
           COUNT(*) AS n_connections
    FROM   train_connections
    GROUP  BY destination_station, source_month
    ORDER  BY source_month, destination_station
""", engine)

print(f'Successfully loaded months: {len(loaded_months)}')
display(loaded_months)

print('\nConnections per station per month:')
pivot = months_by_station.pivot(
    index='source_month', columns='destination_station', values='n_connections'
).fillna(0).astype(int)
display(pivot)

# %% [markdown]
# **Hinweis:** Einige Monate enthalten fehlende Werte. Ursache sind beschädigte Downloads sowie fehlerhafte Komprimierungseinstellungen beim Herunterladen. Das Download-Skript konnte den Inhalt dieser Dateien nicht einlesen.

# %% [markdown]
# ### Zusammenfassung der Datenqualität

# %% [markdown]
# Auf Basis der obigen Prüfungen ist der Datensatz für die Analyse geeignet:
#
# - **Verspätungsdaten**: `arrival_delay_min` ist vollständig und enthält keine unerwarteten NULL-Werte. Die Verteilung ist realistisch und konsistent mit den veröffentlichten SBB-Statistiken.
# - **Niederschlagsdaten**: Die Abdeckung ist hoch; die verwendete NULL-Fill-Strategie (Forward-/Backward-Fill innerhalb des Tages) hat die meisten Sensorlücken erfolgreich geschlossen.
# - **Zeitliche Abdeckung:** Siehe die zuvor dargestellte Vollständigkeitstabelle. Eventuelle fehlende Monate werden als Einschränkung des Analyseumfangs berücksichtigt.
#
# **Bekannte, weitergeführte Einschränkungen:**
# - Nachtüberfahrten werden bewusst ausgeschlossen (Abfahrt und Ankunft an unterschiedlichen Tagen).
# - Ausgefallene Züge sind per Design nicht enthalten.
# - MeteoSwiss-Stationen (Fluntern, Binningen, Zollikofen) dienen als Proxy für städtische Niederschläge und bilden die Wetterbedingungen entlang der gesamten Zugstrecke nicht vollständig ab.

# %% [markdown]
# ## 3.4 Explorative Analyse
#
# Zürich HB ist der am stärksten verspätete Bahnhof; Bern der pünktlichste. Wochentag und Saisonalität wirken als erkennbare Störfaktoren. Fahrten bei Regen liegen tendenziell leicht höher auf der Verspätungsachse, allerdings ist die Überlappung mit trockenen Fahrten deutlich ausgeprägt.

# %% [markdown]
# Wir analysieren die Daten zunächst visuell, bevor statistische Tests angewendet werden. Ziel ist es, Muster zu erkennen, Anomalien zu identifizieren und ein besseres Verständnis für den Zusammenhang zwischen Niederschlag und Verspätung zu entwickeln.
#
# Alle Diagramme verwenden konsistente Stationsfarben:
# **Zürich HB** = blau, **Basel SBB** = rot, **Bern** = grün.

# %% [markdown]
# ### Verspätung nach Bahnhof

# %% [markdown]
# Ein Boxplot zeigt die Verteilung der Verspätungen pro Bahnhof. Dadurch wird sichtbar, ob bestimmte Stationen systematisch pünktlicher sind oder eine höhere Streuung aufweisen als andere — eine wichtige Grundlage, bevor Niederschlag als erklärende Variable eingeführt wird.

# %%
fig, ax = plt.subplots(figsize=(10, 6))
station_order = ['Zürich HB', 'Basel SBB', 'Bern']

sns.boxplot(
    data=df, x='destination_station', y='arrival_delay_min',
    hue='destination_station', order=station_order,
    palette=STATION_COLORS, showfliers=False, legend=False, ax=ax,
)
ax.set_title('Arrival Delay Distribution by Station (outliers hidden)', fontsize=14)
ax.set_xlabel('Station')
ax.set_ylabel('Arrival Delay (minutes)')
ax.axhline(0, color='grey', linewidth=0.8, linestyle='--', label='On time')
ax.legend()
plt.tight_layout()
plt.show()

print('Median delay per station:')
print(df.groupby('destination_station')['arrival_delay_min'].median().round(2))

# %% [markdown]
# Der Boxplot zeigt Unterschiede in der Pünktlichkeitsverteilung auf Ebene der Bahnhöfe. Negative Verspätungen (frühere Ankunft als geplant) sind möglich und stellen gültige Werte dar.
#
# Der Interquartilsabstand (IQR) macht sichtbar, wie stark die Verspätungen unabhängig vom Wetter innerhalb eines Bahnhofs variieren. Stationen mit einer höheren Grundvarianz können eine schwächere Korrelation mit Niederschlag aufweisen, da andere Einflussfaktoren ihre Verspätungsstruktur dominieren.

# %% [markdown]
# ### Verspätung nach Monat

# %% [markdown]
# Saisonale Muster sind relevant: Wintermonate (Schnee, Eis) und Herbstmonate (Laub auf den Gleisen) beeinflussen die Pünktlichkeit bekanntermassen auch unabhängig vom Regen.
#
# Wir visualisieren daher die monatlichen Median-Verspätungen pro Bahnhof, um saisonale Effekte zu erkennen. Diese Darstellung ist nur dann sinnvoll interpretierbar, wenn Daten über mehrere Monate hinweg vorliegen.

# %%
n_months = df['year_month'].nunique()

if n_months < 2:
    print(f'ℹ️  Only {n_months} month(s) loaded — seasonal plot requires at least 2 months.')
    print('   Re-run this cell after more data is collected.')
else:
    monthly = (
        df.groupby(['year_month', 'destination_station'])['arrival_delay_min']
        .median()
        .reset_index()
        .rename(columns={'arrival_delay_min': 'median_delay'})
    )

    fig, ax = plt.subplots(figsize=(13, 5))
    for station, grp in monthly.groupby('destination_station'):
        grp_sorted = grp.sort_values('year_month')
        ax.plot(
            grp_sorted['year_month'], grp_sorted['median_delay'],
            marker='o', label=station, color=STATION_COLORS[station]
        )
    ax.set_title('Median Arrival Delay by Month and Station', fontsize=14)
    ax.set_xlabel('Month')
    ax.set_ylabel('Median Delay (minutes)')
    ax.tick_params(axis='x', rotation=45)
    ax.legend(title='Station')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# Saisonale Muster, sofern vorhanden, sind hier sichtbar. Monate mit erhöhten Verspätungen über alle Stationen hinweg deuten auf systemische Einflussfaktoren hin (Winterwetter, Ferienverkehr) und weniger auf reinen Niederschlag als Ursache.
#
# Monate, in denen einzelne Bahnhöfe von den anderen abweichen, können hingegen auf lokale Infrastrukturprobleme oder stationsspezifische Störungen hinweisen.

# %% [markdown]
# ### Verstpätung nach Wochentag

# %% [markdown]
# Wochentagseffekte sind ein bekannter Störfaktor: Die Hauptverkehrszeiten an Werktagen erzeugen ein anderes Verspätungsprofil als Wochenenden.
#
# Das Verständnis dieses Musters ist wichtig für die Interpretation des Niederschlagsmodells, da dieses nicht für den Wochentag kontrolliert.

# %%
day_labels = {0: 'Sun', 1: 'Mon', 2: 'Tue', 3: 'Wed', 4: 'Thu', 5: 'Fri', 6: 'Sat'}
df['day_label'] = df['day_of_week'].map(day_labels)
day_order = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']

fig, ax = plt.subplots(figsize=(11, 5))
sns.boxplot(
    data=df, x='day_label', y='arrival_delay_min',
    hue='day_label', order=day_order,
    palette=['steelblue'] * 7,
    showfliers=False, legend=False, ax=ax,
)
ax.set_title('Arrival Delay by Day of Week (outliers hidden)', fontsize=14)
ax.set_xlabel('Day of Week')
ax.set_ylabel('Arrival Delay (minutes)')
ax.axhline(0, color='grey', linewidth=0.8, linestyle='--')
plt.tight_layout()
plt.show()

# %% [markdown]
# Werktage zeigen typischerweise höhere Verspätungen als Wochenenden, bedingt durch ein höheres Verkehrsaufkommen. Freitagnachmittage gehören häufig zu den am stärksten verspäteten Zeitfenstern im europäischen Bahnverkehr, während Züge am Sonntag meist am pünktlichsten sind.
#
# Diese Muster bestätigen, dass der Wochentag ein relevanter Störfaktor ist, der im Niederschlagsmodell nicht berücksichtigt wird. Diese Einschränkung wird in Abschnitt 5 entsprechend berücksichtigt.

# %% [markdown]
# ### Niederschlagsverteilung pro Stadt und Monat

# %% [markdown]
# Die Autor*innen visualisieren, wie sich der Niederschlag über Städte und Monate hinweg verändert, um den meteorologischen Kontext des Datensatzes besser zu verstehen.
#
# Eine ungleich verteilte Niederschlagsmenge über die Monate hinweg beeinflusst, wie repräsentativ die Korrelationsresultate tatsächlich sind. Insbesondere können einzelne Monate mit sehr wenigen Regenereignissen die statistische Aussagekraft der wetterbasierten Analyse einschränken.

# %%
if n_months < 2:
    print(f'ℹ️  Only {n_months} month(s) loaded — monthly precipitation chart requires at least 2 months.')
else:
    precip_monthly = (
        df.dropna(subset=['median_precip_mm'])
        .groupby(['year_month', 'destination_city'])['median_precip_mm']
        .mean()
        .reset_index()
    )
    city_colors = {'Zürich': '#1f77b4', 'Basel': '#d62728', 'Bern': '#2ca02c'}
    months_sorted = sorted(precip_monthly['year_month'].unique())
    cities = sorted(precip_monthly['destination_city'].unique())
    x = np.arange(len(months_sorted))
    width = 0.25

    fig, ax = plt.subplots(figsize=(13, 5))
    for i, city in enumerate(cities):
        city_data = (
            precip_monthly[precip_monthly['destination_city'] == city]
            .set_index('year_month')['median_precip_mm']
            .reindex(months_sorted)
        )
        ax.bar(
            x + i * width, city_data.values,
            width, label=city, color=city_colors.get(city, 'grey')
        )

    ax.set_title('Mean Trip-Window Precipitation by City and Month', fontsize=14)
    ax.set_xlabel('Month')
    ax.set_ylabel('Mean Median Precipitation (mm)')
    ax.set_xticks(x + width)
    ax.set_xticklabels(months_sorted, rotation=45)
    ax.legend(title='City')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# Basel (Rheintal) erhält typischerweise weniger Niederschlag als Bern (Voralpenregion) und Zürich (Mittelland).
#
# Monate mit hoher durchschnittlicher Niederschlagsmenge sind für die Korrelationsanalyse besonders wichtig, da sie den relevanten Signalanteil liefern, den wir untersuchen.

# %% [markdown]
# ### Niederschlag vs. Verspätung (Streudiagramm)

# %% [markdown]
# Das Streudiagramm ist der direkteste visuelle Test der Hypothese: Haben Fahrten bei stärkerem Niederschlag längere Verspätungen?
#
# Ein Subplot pro Bahnhof ermöglicht es, zu erkennen, ob sich ein möglicher Zusammenhang zwischen den Standorten unterscheidet. Eine Regressionslinie ist überlagert, um Richtung und Stärke eines linearen Trends zu verdeutlichen.

# %%
df_clean = df.dropna(subset=['median_precip_mm', 'arrival_delay_min'])
stations = ['Zürich HB', 'Basel SBB', 'Bern']

fig, axes = plt.subplots(1, 3, figsize=(15, 5), sharey=True)

for ax, station in zip(axes, stations):
    subset = df_clean[df_clean['destination_station'] == station]
    ax.scatter(
        subset['median_precip_mm'], subset['arrival_delay_min'],
        alpha=0.2, s=8, color=STATION_COLORS[station]
    )
    # Regression line
    if len(subset) > 1:
        m, b = np.polyfit(subset['median_precip_mm'], subset['arrival_delay_min'], 1)
        x_line = np.linspace(subset['median_precip_mm'].min(), subset['median_precip_mm'].max(), 100)
        ax.plot(x_line, m * x_line + b, color='black', linewidth=1.5, label=f'slope={m:.3f}')
        ax.legend(fontsize=9)
    ax.set_title(station, fontsize=12)
    ax.set_xlabel('Median Precipitation (mm)')

axes[0].set_ylabel('Arrival Delay (minutes)')
fig.suptitle('Precipitation vs. Arrival Delay by Station', fontsize=14, y=1.01)
plt.tight_layout()
plt.show()

# %% [markdown]
# Die Streudiagramme vermitteln einen ersten visuellen Eindruck des Zusammenhangs zwischen Niederschlag und Verspätung.
#
# Eine positive Steigung der Regressionslinie deutet darauf hin, dass Fahrten bei stärkerem Niederschlag tendenziell später ankommen. Die hohe Streuung (breite vertikale Verteilung bei jedem Niederschlagsniveau) bestätigt jedoch, dass Niederschlag allein nur einen kleinen Teil der Varianz in den Verspätungen erklärt — konsistent mit einem niedrigen R²-Wert, wie er für ein Modell mit nur einem Prädiktor zu erwarten ist.

# %% [markdown]
# ## 3.4 Korrelationsanalyse
#
# Niederschlag ist statistisch signifikant mit Verspätung korreliert (Spearman ρ = 0,074 gesamt, p < 0,001), der Effekt zeigt jedoch eine binäre Schwelle — trocken vs. nass — und keine lineare Beziehung. Die Regenintensität sagt die Verspätungsintensität nicht voraus.

# %% [markdown]
# Die Autor*innen quantifizieren den statistischen Zusammenhang zwischen`median_precip_mm` und
# `arrival_delay_min` mithilfe zweier komplementärer Masse:
#
# - **Pearson r** — misst die lineare Korrelation; empfindlich gegenüber Ausreissern.
# - **Spearman ρ** — misst die monotone Korrelation; robust gegenüber Ausreissern und nicht-normalverteilten Daten.
#
# Beide Kennzahlen werden sowohl pro Bahnhof als auch insgesamt berechnet, jeweils inklusive p-Werten zur Beurteilung der statistischen Signifikanz. Als Schwelle für Signifikanz wird **p < 0,05** verwendet.

# %% [markdown]
# ### Pearson- und Spearman-Korrelationstabelle

# %%
df_corr = df.dropna(subset=['median_precip_mm', 'arrival_delay_min'])

rows = []
for label, subset in [('Overall', df_corr)] + [
    (s, df_corr[df_corr['destination_station'] == s]) for s in ['Zürich HB', 'Basel SBB', 'Bern']
]:
    if len(subset) < 3:
        continue
    pr, pp = stats.pearsonr(subset['median_precip_mm'], subset['arrival_delay_min'])
    sr, sp = stats.spearmanr(subset['median_precip_mm'], subset['arrival_delay_min'])
    rows.append({
        'Scope':          label,
        'n':              len(subset),
        'Pearson r':      round(pr, 4),
        'Pearson p':      round(pp, 4),
        'Pearson sig':    '✓' if pp < 0.05 else '✗',
        'Spearman ρ':     round(sr, 4),
        'Spearman p':     round(sp, 4),
        'Spearman sig':   '✓' if sp < 0.05 else '✗',
    })

corr_table = pd.DataFrame(rows)
display(corr_table)

# %% [markdown]
# Alle Korrelationen sind **statistisch signifikant** (p ≈ 0.0) über alle betrachteten Ebenen hinweg.
# Bei über 4 Millionen Beobachtungen sind selbst sehr kleine Effekte nachweisbar — die Signifikanz spiegelt hier vor allem die grosse Stichprobengrösse wider, nicht zwingend eine praktische Relevanz.
#
# Die Koeffizientenwerte erzählen die eigentliche Geschichte:
#
# | Scope | Pearson r | Spearman ρ |
# |---|---|---|
# | Overall | 0.012 | 0.074 |
# | Zürich HB | 0.010 | 0.089 |
# | Basel SBB | 0.017 | 0.046 |
# | Bern | 0.024 | 0.063 |
#
# Die Spearman ρ-Werte (0.046–0.089) sind hier aussagekräftiger als Pearson, da die Verspätungsverteilung nicht normalverteilt ist. Ein Gesamtwert von ρ = 0,074 deutet auf eine **schwache, aber reale monotone Beziehung** hin: Fahrten bei stärkerem Niederschlag kommen tendenziell etwas später an, jedoch erklärt der Niederschlag nur einen kleinen Teil der Gesamtvarianz.
#
# Zürich HB zeigt die stärkste monotone Beziehung (ρ = 0,089), möglicherweise weil es ein zentraler Umsteigeknoten ist, an dem sich wetterbedingte Verzögerungen über Anschlussverbindungen hinweg kumulieren können.

# %% [markdown]
# ### Korrelations-Heatmap

# %% [markdown]
# Die Heatmap visualisiert die Korrelationsmatrix aller numerischen Variablen in der Analyse-Ansicht. Dadurch wird sichtbar, ob andere Variablen stärker mit der Verspätung korreliert sind als der Niederschlag.

# %%
numeric_cols = ['arrival_delay_min', 'trip_duration_min', 'median_precip_mm',
                'day_of_week', 'month']
corr_matrix = df[numeric_cols].corr(method='spearman')

fig, ax = plt.subplots(figsize=(8, 6))
sns.heatmap(
    corr_matrix, annot=True, fmt='.3f', cmap='coolwarm',
    center=0, vmin=-1, vmax=1, square=True, ax=ax,
    linewidths=0.5
)
ax.set_title('Spearman Correlation Matrix (Numeric Variables)', fontsize=13)
plt.tight_layout()
plt.show()

# %% [markdown]
# Die Heatmap zeigt die vollständige Korrelationsstruktur. Die Beziehung zwischen `median_precip_mm` und
# `arrival_delay_min` ist dabei von primärem Interesse. Falls `month` oder
# `day_of_week` stärkere Korrelationen mit der Verspätung aufweisen, bestätigt dies, dass zeitliche Störfaktoren eine grössere Rolle spielen als der Niederschlag.

# %% [markdown]
# ### Korrelation nach Niederschlagskategorie

# %% [markdown]
# Anstatt den Niederschlag als kontinuierliche Variable zu behandeln, gruppieren wir ihn in vier betriebliche Kategorien und vergleichen die durchschnittliche Verspätung zwischen diesen Gruppen.
#
# Dadurch lässt sich erkennen, ob die Beziehung monoton ist (mehr Regen = mehr Verspätung) oder ob eher ein Schwellenwert-Effekt vorliegt.

# %%
cat_order = ['dry', 'light', 'moderate', 'heavy']
df_cat = df.dropna(subset=['median_precip_mm', 'arrival_delay_min', 'precip_category'])
df_cat = df_cat[df_cat['precip_category'] != 'unknown']

# Summary table
cat_summary = (
    df_cat.groupby(['precip_category', 'destination_station'])['arrival_delay_min']
    .agg(mean_delay='mean', median_delay='median', n='count')
    .round(3)
    .reset_index()
)
print('Mean and median delay by precipitation category and station:')
display(cat_summary)

# Bar chart — mean delay per category
overall_cat = (
    df_cat.groupby('precip_category')['arrival_delay_min']
    .mean()
    .reindex(cat_order)
)
fig, ax = plt.subplots(figsize=(8, 5))
overall_cat.plot(kind='bar', color='steelblue', edgecolor='white', ax=ax)
ax.set_title('Mean Arrival Delay by Precipitation Category (Overall)', fontsize=13)
ax.set_xlabel('Precipitation Category')
ax.set_ylabel('Mean Arrival Delay (minutes)')
ax.tick_params(axis='x', rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# Das Balkendiagramm zeigt ein klares monotones Muster bis zu moderatem Niederschlag:
#
# | Category | Basel SBB mean | Bern mean | Zürich HB mean | n (approx) |
# |---|---|---|---|---|
# | dry | 1.712 min | 0.419 min | 1.000 min | ~3.84M |
# | light | 2.327 min | 0.841 min | 1.517 min | ~233K |
# | moderate | 3.179 min | higher | higher | ~3K |
# | heavy | 4.996 min | 0.204 min | 1.016 min | 198–752 |
#
# **Wichtiger Vorbehalt zu Starkregen:**  Die Kategorie „starker Niederschlag“ umfasst lediglich 198 Verbindungen in Basel SBB, 395 in Bern und 752 in Zürich HB – das ist zu wenig für statistisch belastbare Aussagen auf Stationsebene. Der auffällig tiefe Mittelwert in Bern (0,204 min) bei starkem Regen ist sehr wahrscheinlich ein Zufallsartefakt dieser kleinen Stichprobe und kein realer Effekt.
# Die Entwicklung von trocken → leicht → moderat ist dagegen über alle drei Bahnhöfe hinweg konsistent und monoton. Dies stützt die Hypothese, dass mehr Niederschlag mit höheren Verspätungen einhergeht – zumindest bis zur Kategorie „moderat“.

# %% [markdown]
# ### Erkenntnisse und Einschränkungen

# %% [markdown]
# **Zentrale Erkenntnisse aus der Korrelationsanalyse:**
#
# - Niederschlag hat einen **statistisch signifikanten, aber betrieblich kleinen** positiven Effekt auf Ankunftsverspätungen an allen drei Bahnhöfen (Spearman ρ = 0.046–0.089, alle p < 0.001 bei 4’100’349 Beobachtungen).
# - Zürich HB ist am sensitivsten (ρ = 0.089); Basel SBB am wenigsten (ρ = 0.046).
# - Die Entwicklung trocken → leicht → moderat ist monoton und konsistent, jedoch ist die Kategorie „starker Niederschlag“ auf Stationsebene nicht zuverlässig (nur 198–752 Verbindungen).
# - Die statistische Signifikanz bei p≈0.0 ist eine Folge der sehr grossen Stichprobe und nicht Ausdruck hoher praktischer Relevanz. Die Koeffizienten selbst sind die aussagekräftige Grösse.
#
# Einschränkungen:
#
# - **Einzel-Prädiktor:** Niederschlag erklärt nur einen sehr kleinen Anteil der Varianz in den Verspätungen.
# - **Stationsdistanz**: MeteoSwiss-Stationen sind städtische Näherungen und bilden die Bedingungen entlang der gesamten Strecke nicht vollständig ab.
# - **Starker Regen nur eingeschränkt interpretierbar:** Kleine Fallzahlen verhindern robuste Aussagen.
# - **Signifikanz ≠ Relevanz:** p≈0.0 ist bei 4.1 Mio. Beobachtungen erwartbar.

# %% [markdown]
# ### Korrelationsanalyse nach Niederschlags-Subset
#
# Die Gesamt-Spearman-Korrelation von ρ = 0,074 wird über alle 4’100’349 Verbindungen berechnet, wobei der grösste Teil davon trocken ist. Wir gehen davon aus, dass die Korrelation eher durch den Kontrast zwischen trockenen und nassen Beobachtungen entsteht als durch die Intensität des Niederschlags selbst.
# Um dies zu überprüfen, berechnen wir Spearman ρ für drei zunehmend restriktive Teilmengen:
#
# | Subset | Categories included | n | Share |
# |---|---|---|---|
# | **All data** | dry + light + moderate + heavy | 4,100,349 | 100% |
# | **Rain only** | light + moderate + heavy | 264,206 | 6.4% |
# | **Core rain** | light + moderate | 262,861 | 6.4% |
#
# **Definition der Niederschlagskategorien** (from `db/init.sql`):
#
# | Category | `median_precip_mm` range | Hourly equiv. (×6) | App alert |
# |---|---|---|---|
# | dry | = 0.000 mm | 0 mm/h | 🟢 |
# | light | > 0.000 and < 0.500 mm | < 3 mm/h | 🟡 |
# | moderate | ≥ 0.500 and < 2.000 mm | 3–12 mm/h | 🟠 |
# | heavy | ≥ 2.000 mm | > 12 mm/h | 🔴 |
#
# Diese Schwellenwerte beziehen sich auf `median_precip_mm` — den Median der 10-Minuten-Niederschlagsmessungen über das Reisezeitfenster. Die Applikation konvertiert die MeteoSwiss-Stundenprognose (mm/h) in diese Skala, indem sie den Wert durch 6 teilt, bevor die Klassifizierung und Vorhersage erfolgt.

# %%
# Define the three subsets
cat_all       = ['dry', 'light', 'moderate', 'heavy']
cat_rain_only = ['light', 'moderate', 'heavy']
cat_core_rain = ['light', 'moderate']

subsets = {
    'All data (dry+light+mod+heavy)': df[df['precip_category'].isin(cat_all)],
    'Rain only (light+mod+heavy)':    df[df['precip_category'].isin(cat_rain_only)],
    'Core rain (light+moderate)':     df[df['precip_category'].isin(cat_core_rain)],
}

print('Subset sizes:')
for name, subset in subsets.items():
    pct = len(subset) / len(df) * 100
    print(f'  {name:<45} {len(subset):>10,} rows ({pct:.1f}%)')

# %% [markdown]
# ### Spearman-Korrelation pro Teilmenge
#
# Die Autor*innen berechnen Spearman ρ für jede Teilmenge — insgesamt und pro Bahnhof — um zu prüfen, ob eine Einschränkung auf regnerische Bedingungen die Korrelation verstärkt.

# %%
corr_rows = []
for subset_name, subset_df in subsets.items():
    clean = subset_df.dropna(subset=['median_precip_mm', 'arrival_delay_min'])
    for scope in ['Overall', 'Zürich HB', 'Basel SBB', 'Bern']:
        grp = clean if scope == 'Overall' else clean[clean['destination_station'] == scope]
        if len(grp) < 3:
            continue
        rho, p = stats.spearmanr(grp['median_precip_mm'], grp['arrival_delay_min'])
        corr_rows.append({
            'Subset':     subset_name,
            'Scope':      scope,
            'n':          len(grp),
            'Spearman r': round(rho, 4),
            'p-value':    round(p, 4),
            'sig':        'yes' if p < 0.05 else 'no',
        })

corr_subset_df = pd.DataFrame(corr_rows)
display(corr_subset_df)

# %% [markdown]
# Die Resultate widersprechen grösstenteils der ursprünglichen Hypothese, dass sich die Korrelation durch die Einschränkung auf regnerische Bedingungen verstärken würde. Für die meisten betrachteten Teilmengen zeigt sich vielmehr das Gegenteil:
#
# | Subset | Overall | Zürich HB | Basel SBB | Bern |
# |---|---|---|---|---|
# | All data | **0.074** | 0.089 | 0.046 | 0.063 |
# | Rain only | 0.048 | 0.040 | **0.084** | 0.034 |
# | Core rain | 0.050 | 0.042 | **0.082** | 0.037 |
#
# **Auffällige Anomalie — Basel SBB:** Im Gegensatz zu Zürich HB und Bern zeigt Basel SBB in der rain-only-Teilmenge eine *stärkere* Korrelation (ρ = 0,084) als im Gesamtdatensatz (ρ = 0,046). Dies könnte darauf hindeuten, dass dort innerhalb von Niederschlagsphasen die Regenintensität eine höhere Vorhersagekraft für Verspätungen hat als an den anderen Stationen. Aufgrund von nur 27’554 regenbedingten Verbindungen in Basel SBB (vs. 149’646 in Zürich HB) ist dieses Ergebnis jedoch mit Vorsicht zu interpretieren.
#
# **Gesamtinterpretation:**
# Die Gesamtkorrelation ρ sinkt von 0,074 auf etwa 0,048–0,050, wenn trockene Beobachtungen entfernt werden. Dies bestätigt, dass das Signal im Gesamtdatensatz primär aus dem **Kontrast zwischen Null- und Nicht-Null-Niederschlag** stammt.
#
#
# Fahrten bei trockenem Wetter bilden einen grossen, verspätungsarmen Cluster; Fahrten bei Regen liegen leicht höher auf der Verspätungsachse. Sobald die trockenen Beobachtungen entfernt werden, verschwindet der Zusammenhang zwischen Regenintensität und Verspätung weitgehend (mit Basel SBB als teilweiser Ausnahme).
#
# Damit ergibt sich eine präzisere Charakterisierung des Niederschlagseffekts, als es die Gesamtkorrelation ρ = 0,074 allein vermuten liesse.

# %% [markdown]
# ### Streudiagramme nach Teilmengen

# %% [markdown]
# Drei Reihen von Streudiagrammen — eine pro Teilmenge — jeweils mit einer Spalte pro Bahnhof.
#
# Die Steigung der Regressionslinie ist in jedem Subplot annotiert. Der Vergleich der Steigungen über die Reihen hinweg zeigt, wie sich der Zusammenhang zwischen Niederschlag und Verspätung durch die Wahl der Teilmenge verändert.

# %%
stations = ['Zürich HB', 'Basel SBB', 'Bern']
subset_items = list(subsets.items())

fig, axes = plt.subplots(3, 3, figsize=(15, 13))

for row, (subset_name, subset_df) in enumerate(subset_items):
    clean = subset_df.dropna(subset=['median_precip_mm', 'arrival_delay_min'])
    for col, station in enumerate(stations):
        ax = axes[row, col]
        s = clean[clean['destination_station'] == station]
        ax.scatter(
            s['median_precip_mm'], s['arrival_delay_min'],
            alpha=0.15, s=5, color=STATION_COLORS[station]
        )
        if len(s) > 1:
            m, b = np.polyfit(s['median_precip_mm'], s['arrival_delay_min'], 1)
            x_line = np.linspace(s['median_precip_mm'].min(), s['median_precip_mm'].max(), 100)
            ax.plot(x_line, m * x_line + b, color='black', linewidth=1.5)
            ax.set_title(f'{station}  slope={m:.3f}', fontsize=10)
        else:
            ax.set_title(station, fontsize=10)
        ax.set_xlabel('Median Precip (mm)', fontsize=9)
        if col == 0:
            ax.set_ylabel(subset_name + '\n\nDelay (min)', fontsize=9)
        else:
            ax.set_ylabel('Delay (min)', fontsize=9)

fig.suptitle('Precipitation vs. Delay — Scatter Plots by Subset and Station', fontsize=13, y=1.01)
plt.tight_layout()
plt.show()

# %% [markdown]
# Die Streudiagramme bestätigen die Ergebnisse der Teilmengenanalyse auch visuell. In der Zeile mit allen Daten (oben) ist die Regressionssteigung positiv und klar erkennbar — der trockene Cluster bei x = 0 verankert die linke Seite der Beziehung, während die Regenfahrten die Steigung nach oben ziehen.
#
# In den rain-only- und core-rain Zeilen verschwindet dieser trockene Anker. Was übrig bleibt, ist eine nahezu flache Regressionslinie über den gesamten Regenbereich hinweg — die Regenintensität von 0,1 mm bis 2,0 mm steht in keinem konsistenten Zusammenhang mit der Verspätungshöhe. Die Steigung ist in einigen Bahnhöfen praktisch null oder sogar leicht negativ.
#
# Das bestätigt: **Der Niederschlagseffekt ist ein Schwellenwert-Effekt und kein linearer Zusammenhang.**

# %% [markdown]
# ### Korrelations-Heatmaps nach Teilmenge

# %% [markdown]
# Nebeneinander dargestellte Spearman-Korrelations-Heatmaps für alle drei Teilmengen.
# Die Zelle `median_precip_mm` und `arrival_delay_min` ist der zentrale Vergleich.
# Eine stärkere Farbe (höherer absoluter Wert) in den regenbeschränkten Teilmengen bestätigt die Verdünnungshypothese.
#
# Eine feste Farbskala über alle drei Panels stellt sicher, dass die Zellen direkt vergleichbar sind.

# %%
numeric_cols = ['arrival_delay_min', 'trip_duration_min', 'median_precip_mm',
                'day_of_week', 'month']

fig, axes = plt.subplots(1, 3, figsize=(18, 5))

for i, (ax, (subset_name, subset_df)) in enumerate(zip(axes, subset_items)):
    corr = subset_df[numeric_cols].corr(method='spearman')
    sns.heatmap(
        corr, annot=True, fmt='.3f', cmap='coolwarm',
        center=0, vmin=-0.3, vmax=0.3,
        square=True, linewidths=0.5,
        ax=ax, cbar=(i == 2),
    )
    ax.set_title(subset_name, fontsize=11)

fig.suptitle('Spearman Correlation Heatmaps by Precipitation Subset', fontsize=13)
plt.tight_layout()
plt.show()

# %% [markdown]
# Die drei Heatmaps bestätigen visuell, was die Korrelations-Tabelle bereits numerisch zeigt. Die Zelle `median_precip_mm` × `arrival_delay_min` wird **schwächer** (hellere Farbe), wenn man vom gesamten Datensatz (links) zu den Regen-Teilsets (rechts) übergeht – also genau das Gegenteil der ursprünglichen Subset-Hypothese.
#
# Die Heatmap des Gesamtdatensatzes zeigt die stärkste Niederschlags–Verspätungs-Beziehung, weil sie den Kontrast zwischen trockenen und nassen Bedingungen vollständig enthält. In den „Rain-only“- und „Core-Rain“-Teilmengen geht dieser Kontrast verloren, wodurch das Niederschlagssignal praktisch gegen Null tendiert.
#
# **Schlussfolgerung aus der Subset-Analyse:** Das Modell auf Basis des gesamten Datensatzes ist die richtige Wahl für jede prädiktive Anwendung. Eine Einschränkung auf Regenbedingungen verbessert das Modell nicht – sie verschlechtert es, weil genau der relevante Signalanteil im Datensatz entfernt wird.

# %% [markdown]
# ## 3.5 Prädiktives Modell
#
# Niederschlag allein kann individuelle Verspätungen nicht zuverlässig vorhersagen (R² ≈ 0.000). Eine Einschränkung auf Regenbedingungen verschlechtert die Modellleistung und bestätigt den Threshold-Effekt. Das beste Modell (Random Forest, RMSE = 6.610) wird für den Einsatz in Phase 5 gespeichert.

# %% [markdown]
# Die Autor*innen trainieren zwei Modelle, um `arrival_delay_min` aus `median_precip_mm` vorherzusagen:
#
# 1. **Lineare Regression** – das einfachste mögliche Modell; dient als Baseline.
# 2. **Random Forest Regressor** ein nichtlineares Ensemble-Modell, das Schwellenwerteffekte und Interaktionen erfassen kann.
#
# Der Train/Test-Split erfolgt **zeitbasiert (80/20 nach Datum)** — nicht zufällig.
# Ein zufälliger Split würde zukünftige Informationen ins Training leaken und dadurch die Metriken künstlich verbessern.
#
# Das Modell mit der besseren Leistung (niedrigerer RMSE auf dem Testset) wird als `models/model_all_data.pkl`
# gespeichert und in Phase 5 verwendet. Diese Datei ist die einzige externe Abhängigkeit der Webanwendung.

# %% [markdown]
# ### Daten-Suffizienz-Check

# %% [markdown]
# Eine zuverlässige Modellevaluation setzt ausreichend Daten voraus. Bei weniger als 6 Monaten führt der zeitbasierte Train/Test-Split dazu, dass der Trainingsdatensatz zu klein für eine stabile Generalisierung ist und der Testdatensatz zu klein, um robuste Metriken zu liefern.
#
# Dieser Check wird deshalb vor dem eigentlichen Training durchgeführt, um sicherzustellen, dass die Evaluation nicht durch zu geringe Datenmenge verzerrt wird.

# %%
n_months_loaded = df['year_month'].nunique()
MIN_MONTHS = 6

if n_months_loaded < MIN_MONTHS:
    print(f'⚠️  Insufficient data for reliable model training.')
    print(f'   Only {n_months_loaded} month(s) loaded — minimum {MIN_MONTHS} required.')
    print(f'   Re-run this section after the full dataset is collected.')
else:
    print(f'✓ {n_months_loaded} months loaded — proceeding with model training.')

# %% [markdown]
# ### Features und zeitliche Aufteilung vorbereiten

# %%
if n_months_loaded >= MIN_MONTHS:
    # Drop rows with missing predictor or target
    df_model = (
        df.dropna(subset=['median_precip_mm', 'arrival_delay_min'])
        .sort_values('betriebstag')
        .reset_index(drop=True)
    )

    X = df_model[['median_precip_mm']].values
    y = df_model['arrival_delay_min'].values

    # Temporal 80/20 split — first 80% of sorted dates = train
    split_idx = int(len(df_model) * 0.80)
    X_train, X_test = X[:split_idx], X[split_idx:]
    y_train, y_test = y[:split_idx], y[split_idx:]

    split_date = df_model['betriebstag'].iloc[split_idx]
    print(f'Training set: {split_idx:,} records (up to {split_date})')
    print(f'Test set:     {len(df_model) - split_idx:,} records (from {split_date})')

# %% [markdown]
# ### Beide Modelle trainieren und evaluieren

# %%
if n_months_loaded >= MIN_MONTHS:
    def evaluate_model(name, model, X_tr, y_tr, X_te, y_te):
        """Fit model, compute test metrics, return dict."""
        model.fit(X_tr, y_tr)
        y_pred = model.predict(X_te)
        rmse = float(np.sqrt(mean_squared_error(y_te, y_pred)))  # squared=False removed in sklearn 1.4
        return {
            'model':    name,
            'MAE':      round(mean_absolute_error(y_te, y_pred), 4),
            'RMSE':     round(rmse, 4),
            'R2':       round(r2_score(y_te, y_pred), 4),
            'instance': model,
            'y_pred':   y_pred,
        }

    lr_result = evaluate_model('Linear Regression', LinearRegression(),
                               X_train, y_train, X_test, y_test)
    rf_result = evaluate_model('Random Forest',
                               RandomForestRegressor(n_estimators=100, random_state=42),
                               X_train, y_train, X_test, y_test)

    metrics_df = pd.DataFrame([{
        k: v for k, v in r.items() if k not in ('instance', 'y_pred')
    } for r in [lr_result, rf_result]])
    print('Model comparison on test set:')
    display(metrics_df)

# %% [markdown]
# ### Residual- und Vorhersageplots

# %%
if n_months_loaded >= MIN_MONTHS:
    fig, axes = plt.subplots(2, 2, figsize=(14, 10))

    for col, result in enumerate([lr_result, rf_result]):
        y_pred = result['y_pred']
        residuals = y_test - y_pred
        name = result['model']

        # Predicted vs Actual
        axes[0, col].scatter(y_test, y_pred, alpha=0.2, s=8, color='steelblue')
        lim = [min(y_test.min(), y_pred.min()), max(y_test.max(), y_pred.max())]
        axes[0, col].plot(lim, lim, 'k--', linewidth=1)
        axes[0, col].set_title(f'{name} — Predicted vs Actual', fontsize=11)
        axes[0, col].set_xlabel('Actual Delay (min)')
        axes[0, col].set_ylabel('Predicted Delay (min)')

        # Residuals
        axes[1, col].scatter(y_pred, residuals, alpha=0.2, s=8, color='coral')
        axes[1, col].axhline(0, color='black', linewidth=1)
        axes[1, col].set_title(f'{name} — Residuals', fontsize=11)
        axes[1, col].set_xlabel('Predicted Delay (min)')
        axes[1, col].set_ylabel('Residual (min)')

    plt.suptitle('Model Diagnostics', fontsize=14)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# **Vorhergesagt vs. tatsächlich**: Punkte nahe an der Diagonalen deuten auf genaue Vorhersagen hin.
# Bei einem einzelnen Prädiktor ist jedoch eine grosse Streuung zu erwarten – das Modell erfasst den durchschnittlichen Trend, aber nicht die individuelle Variabilität der Fahrten.
#
# **Residuals**: idealerweise um null zentriert und ohne erkennbares Muster. Ein systematisches Muster (z. B. konsequentes Unterschätzen grosser Verspätungen) weist darauf hin, dass dem Modell Struktur fehlt, die mit einem reichhaltigeren Merkmalsset erfasst werden könnte.

# %% [markdown]
# ### Modellauswahl und Persistenz

# %% [markdown]
# Das Modell mit dem tieferen RMSE auf dem Test-Set wird als Gewinner ausgewählt. Der RMSE bestraft grosse Fehler stärker als der MAE, weshalb er sich als Hauptmetrik für diesen Anwendungsfall zur Verspätungsvorhersage eignet, da grosse Abweichungen besonders kostspielig sind.

# %%
if n_months_loaded >= MIN_MONTHS:
    from datetime import timezone

    # Select winner by RMSE
    winner = min([lr_result, rf_result], key=lambda r: r['RMSE'])
    print(f'Winner: {winner["model"]} (RMSE: {winner["RMSE"]:.4f})')

    # Save model
    models_dir = Path('..') / 'models'
    models_dir.mkdir(exist_ok=True)

    model_path = models_dir / 'model.pkl'
    joblib.dump(winner['instance'], model_path)

    # Save metadata
    metadata = {
        'model_type':         winner['model'],
        'MAE':                winner['MAE'],
        'RMSE':               winner['RMSE'],
        'R2':                 winner['R2'],
        'trained_at':         datetime.now(timezone.utc).isoformat(),
        'n_training_samples': int(len(X_train)),
        'n_test_samples':     int(len(X_test)),
        'feature':            'median_precip_mm',
        'target':             'arrival_delay_min',
    }
    with open(models_dir / 'model_metadata.json', 'w') as f:
        json.dump(metadata, f, indent=2)

    print(f'✓ Model saved to {model_path}')
    print(f'✓ Metadata saved to {models_dir / "model_metadata.json"}')

# %% [markdown]
# ### Diskussion

# %% [markdown]
# **Interpretation der Kennzahlen:**
# - **MAE** (Mean Absolute Error): der durchschnittliche Vorhersagefehler in Minuten. Ein MAE von 1.46 Minuten bedeutet, dass das Modell im Schnitt um etwa 1.5 Minuten danebenliegt.
# - **RMSE** (Root Mean Squared Error): bestraft grosse Fehler stärker.
# Mit 6.61 Minuten liegt er deutlich höher als der MAE, was die rechtsschiefe Verteilung der Verspätungen mit gelegentlichen Ausreissern widerspiegelt.
# - **R²**: Anteil der erklärten Varianz der Verspätung.
# Ein R² von –0.000 bedeutet, dass Niederschlag praktisch keine Varianz der Verspätungen erklärt – das Modell ist nicht besser als eine einfache Mittelwertvorhersage für jede Fahrt.
#
# **Warum ein R² nahe null zu erwarten ist:**
# Zugverspätungen werden von vielen Faktoren beeinflusst – Infrastrukturstörungen, Personalverfügbarkeit, Passagieraufkommen, Abhängigkeiten von Anschlussverbindungen und mehr. Niederschlag ist nur ein kleiner Einfluss in einem sehr verrauschten System. Ein R² nahe null bedeutet nicht, dass das Modell falsch ist, sondern dass es die Grenzen eines einzelnen Prädiktors korrekt widerspiegelt.
#
# Das Modell wird gespeichert und ist bereit für den Einsatz in Phase 5.

# %% [markdown]
# ### Modellvarianten für das Niederschlags-Subset

# %% [markdown]
# Auf Basis der obigen Korrelationsanalyse trainieren wir drei Modellvarianten – je eine pro Niederschlags-Subset –, um zu prüfen, ob sich ein auf Regenbedingungen eingeschränktes Modell zur Verspätungsvorhersage verbessert.
#
# Jede Variante verwendet denselben Aufbau wie das Basismodell:
# - Feature: `median_precip_mm`
# - Zielvariable: `arrival_delay_min`
# - Zeitbasierter 80/20 Train/Test-Split nach Datum
# - Vergleich von Linearer Regression und Random Forest; das beste Modell wird anhand des RMSE gespeichert
#
# Die Korrelationsanalyse der Subsets hat gezeigt, dass die Einschränkung auf Regenbedingungen die Korrelation sogar abschwächt. Nun überprüfen wir auf Modellebene, ob sich dieses Muster bestätigt – führt ein auf Regen eingeschränktes Modell zu besseren oder schlechteren Metriken?

# %%
if n_months_loaded >= MIN_MONTHS:
    # Redefine category lists here so Section 4 is self-contained
    cat_all       = ['dry', 'light', 'moderate', 'heavy']
    cat_rain_only = ['light', 'moderate', 'heavy']
    cat_core_rain = ['light', 'moderate']

    variant_results = []

    variant_subsets = {
        'all_data':  df[df['precip_category'].isin(cat_all)],
        'rain_only': df[df['precip_category'].isin(cat_rain_only)],
        'core_rain': df[df['precip_category'].isin(cat_core_rain)],
    }

    for variant_name, variant_df in variant_subsets.items():
        vm = (
            variant_df.dropna(subset=['median_precip_mm', 'arrival_delay_min'])
            .sort_values('betriebstag')
            .reset_index(drop=True)
        )
        if len(vm) < 100:
            print(f'Skipping {variant_name} — too few rows ({len(vm)})')
            continue

        vX = vm[['median_precip_mm']].values
        vy = vm['arrival_delay_min'].values
        split = int(len(vm) * 0.80)
        vX_tr, vX_te = vX[:split], vX[split:]
        vy_tr, vy_te = vy[:split], vy[split:]

        for model_name, model in [
            ('Linear Regression', LinearRegression()),
            ('Random Forest', RandomForestRegressor(n_estimators=100, random_state=42)),
        ]:
            model.fit(vX_tr, vy_tr)
            vy_pred = model.predict(vX_te)
            variant_results.append({
                'subset':   variant_name,
                'model':    model_name,
                'n_train':  split,
                'n_test':   len(vm) - split,
                'MAE':      round(mean_absolute_error(vy_te, vy_pred), 4),
                'RMSE':     round(float(np.sqrt(mean_squared_error(vy_te, vy_pred))), 4),
                'R2':       round(r2_score(vy_te, vy_pred), 4),
                '_model':   model,
                '_vy_te':   vy_te,
                '_vy_pred': vy_pred,
            })

    variant_display = pd.DataFrame([
        {k: v for k, v in r.items() if not k.startswith('_')}
        for r in variant_results
    ])
    print('Model variant comparison:')
    display(variant_display)

# %% [markdown]
# Die Resultate bestätigen das Ergebnis der Korrelationsanalyse auf Modellebene:
#
# - **all_data** (RF): RMSE=6.610, R²=–0.000 — Baseline-Modell
# - **rain_only** (RF): RMSE=7.824, R²=–0.002 — schlechter als all_data
# - **core_rain** (RF): RMSE=7.801, R²=–0.001 — schlechter als all_data
#
# Alle R²-Werte liegen auf dem Test-Set nahe bei oder unter null. Ein negativer R² bedeutet, dass das Modell geringfügig schlechter abschneidet als eine einfache Mittelwertvorhersage für jede Verbindung – mit anderen Worten: Niederschlag ist kein nützlicher Prädiktor für individuelle Verspätungen, unabhängig davon, wie die Daten gefiltert werden.
#
# Das all_data-Modell ist die am wenigsten schlechte Option, da es den Kontrast zwischen trockenen und nassen Bedingungen beibehält – das einzige Signal, das Niederschlag überhaupt liefert. Die Subsets rain_only und core_rain verlieren diesen Kontrast und führen entsprechend zu höheren RMSE- und schlechteren R²-Werten.
#
# **Hinweis zur Vergleichbarkeit von RMSE/MAE:** MSE und MAE sind zwischen Subsets nur eingeschränkt vergleichbar, da jedes Subset eine andere Verteilung der Verspätungen aufweist. Für den Vergleich über Subsets hinweg ist hier einzig R² wirklich aussagekräftig.

# %%
if n_months_loaded >= MIN_MONTHS:
    subset_order  = ['all_data', 'rain_only', 'core_rain']
    subset_labels = [
        'All data\n(dry+light+mod+heavy)',
        'Rain only\n(light+mod+heavy)',
        'Core rain\n(light+moderate)',
    ]
    model_names  = ['Linear Regression', 'Random Forest']
    model_colors = ['#4878d0', '#ee854a']
    x = np.arange(len(subset_order))
    width = 0.35

    fig, ax = plt.subplots(figsize=(10, 5))
    for i, (mname, mcolor) in enumerate(zip(model_names, model_colors)):
        r2_vals = [
            next((r['R2'] for r in variant_results
                  if r['subset'] == s and r['model'] == mname), 0)
            for s in subset_order
        ]
        bars = ax.bar(x + i * width, r2_vals, width,
                      label=mname, color=mcolor, alpha=0.85)
        ax.bar_label(bars, fmt='%.4f', fontsize=9, padding=2)

    ax.set_title('R² by Precipitation Subset and Model', fontsize=13)
    ax.set_xlabel('Precipitation Subset')
    ax.set_ylabel('R² (test set)')
    ax.set_xticks(x + width / 2)
    ax.set_xticklabels(subset_labels, fontsize=10)
    ax.legend()
    plt.tight_layout()
    plt.show()

# %% [markdown]
# Das R²-Balkendiagramm zeigt, dass alle Werte nahe bei oder unter null liegen – dies bestätigt, dass Niederschlag allein die individuellen Zugverspätungen in keiner Subset-Konfiguration zuverlässig vorhersagen kann.
#
# Die all_data-Balken liegen am nächsten bei null (am wenigsten negativ) und machen das Modell mit dem vollständigen Datensatz zur besten verfügbaren Option für Phase 5. Die rain-only- und core-rain-Balken sind stärker negativ, was bestätigt, dass die Einschränkung auf Regenbedingungen das einzige Signal entfernt, das Niederschlag überhaupt liefert: den Kontrast zwischen trockenen und nassen Bedingungen.

# %%
if n_months_loaded >= MIN_MONTHS:
    from datetime import timezone

    models_dir = Path('..') / 'models'
    models_dir.mkdir(exist_ok=True)

    # Only save the all_data model — rain_only and core_rain perform worse
    # and have no practical use for Phase 5.
    all_data_candidates = [r for r in variant_results if r['subset'] == 'all_data']
    winner = min(all_data_candidates, key=lambda r: r['RMSE'])

    path = models_dir / 'model_all_data.pkl'
    joblib.dump(winner['_model'], path)

    meta = {
        'model_type':              winner['model'],
        'subset':                  'all_data',
        'categories_included':     cat_all,
        'subset_rationale':        (
            'all_data selected because rain-only and core-rain subsets produce '
            'worse R² by removing the dry vs wet contrast — the only '
            'meaningful precipitation signal in the data.'
        ),
        'MAE':                     winner['MAE'],
        'RMSE':                    winner['RMSE'],
        'R2':                      winner['R2'],
        'trained_at':              datetime.now(timezone.utc).isoformat(),
        'n_training_samples':      int(winner['n_train']),
        'n_test_samples':          int(winner['n_test']),
        'feature':                 'median_precip_mm',
        'target':                  'arrival_delay_min',
    }
    meta_path = models_dir / 'model_all_data_metadata.json'
    with open(meta_path, 'w') as f:
        json.dump(meta, f, indent=2)

    print(f'✓ Saved model_all_data.pkl  ({winner["model"]}, RMSE={winner["RMSE"]:.4f}, R2={winner["R2"]:.4f})')
    print(f'  rain_only and core_rain models not saved — all_data is the best available option.')

# %% [markdown]
# Das Subset-Experiment bestätigt, dass **`model_all_data.pkl` das einzige Modell ist, das sich für Phase 5 zu speichern lohnt.**
#
# Die Varianten rain-only und core-rain schneiden schlechter ab, da sie den Kontrast zwischen trockenen und nassen Bedingungen verlieren – genau dieser Kontrast ist jedoch das einzige relevante Signal, das der Niederschlag liefert.
#
# | Model | RMSE | R² | Verdict |
# |---|---|---|---|
# | `model_all_data.pkl` (Random Forest) | 6.610 | –0.000 | ✓ Use for Phase 5 |
# | rain_only (Random Forest) | 7.824 | –0.002 | ✗ Discarded |
# | core_rain (Random Forest) | 7.801 | –0.001 | ✗ Discarded |
#
# **Wie die Applikation dieses Modell verwendet:** Die Streamlit-Anwendung ruft die stündliche Niederschlagsvorhersage von MeteoSchweiz für die geplante Ankunftszeit des Nutzers ab, konvertiert diese in einen 10-Minuten-Wert (÷ 6) und speist diesen kontinuierlichen Wert direkt in `model_all_data.pkl` ein. Das Modell gibt daraufhin eine prognostizierte Verspätung in Minuten aus.
#
# Zusätzlich zur numerischen Vorhersage zeigt die App eine Niederschlagskategorie als Warnstufe an (🟢 dry / 🟡 light / 🟠 moderate / 🔴 heavy), die aus demselben umgerechneten Wert mithilfe der in Abschnitt 3 definierten Schwellenwerte abgeleitet wird.
#
# Ein obligatorischer Hinweis macht klar, dass das Modell ein R² von ungefähr 0.000 hat und die Vorhersage lediglich einen durchschnittlichen Trend widerspiegelt, nicht jedoch eine präzise Einzelprognose pro Fahrt.

# %% [markdown]
# # 4. Schlussfolgerung
#
# Niederschlag hat einen messbaren, aber operativ kleinen Einfluss auf SBB-Verspätungen (Spearman ρ = 0.074, RMSE = 6.610). Das trainierte Modell wird in einer Streamlit-Webanwendung eingesetzt, die die stündliche MeteoSchweiz-Vorhersage in eine prognostizierte Verspätung in Minuten umrechnet und gleichzeitig eine vierstufige Niederschlagswarnung ausgibt – inklusive eines obligatorischen Hinweises auf das nahezu null liegende R² des Modells.

# %% [markdown]
# ## 4.1 Zusammenfassung der Ergebnisse
#
# Diese Studie analysierte **4,100,349 Zugverbindungen** über **45 Monate
# (Januar 2022 – März 2025)** an drei grossen Schweizer Bahnhöfen: Zürich HB, Basel SBB und Bern.
#
# **Das Schweizer Bahnnetz ist sehr pünktlich.** Die mediane Verspätung bei Ankunft beträgt **0.35 Minuten** über alle Bahnhöfe hinweg. 95% der Züge kommen innerhalb von 3.70 Minuten im Vergleich zum Fahrplan an. Nur 0.10% der Verbindungen (4’004 Fahrten) sind mehr als 60 Minuten verspätet. Zürich HB weist die höchsten Verspätungen auf (Median 0.50 Min), Bern ist am pünktlichsten (Median 0.07 Min).
#
# **Niederschlag hat einen statistisch signifikanten, aber schwachen positiven Effekt auf Verspätungen.**
# Die Spearman-Korrelationen liegen zwischen ρ = 0.046 (Basel SBB) und ρ = 0.089 (Zürich HB), alle signifikant bei p < 0.001. Diese Werte spiegeln jedoch eher die grosse Stichprobe als einen starken praktischen Zusammenhang wider.
#
# **Der Niederschlagseffekt ist ein Schwellenwert-Effekt, kein linearer Zusammenhang.**
# Die Subset-Analyse zeigt, dass das Signal vollständig aus dem
# **Kontrast zwischen trockenen und nassen Bedingungen** stammt — nicht aus der Regenintensität. Wird die Analyse nur auf Regenverbindungen eingeschränkt (leicht + moderat + stark), sinkt Spearman ρ von 0.074 auf 0.048. Das bestätigt: Ob es regnet, spielt leicht eine Rolle – wie stark es regnet nicht.
#
# **Ein Modell mit nur einem Prädiktor kann individuelle Verspätungen nicht zuverlässig vorhersagen.**
# Sowohl lineare Regression als auch Random Forest, trainiert auf 3’280’279 Verbindungen, erreichen auf dem Testset (820’070 Verbindungen) ein R² von ungefähr 0.000 – das Modell ist nicht besser als eine Mittelwertvorhersage für jede Fahrt. Der Random Forest ist minimal besser (RMSE = 6.610, MAE = 1.462, R² ≈ –0.000) und wird als model_all_data.pkl für Phase 5 gespeichert.
#
# Die Subset-Modelle (rain-only RMSE = 7.824, core-rain RMSE = 7.801) schneiden schlechter ab, was bestätigt, dass das All-Data-Modell die richtige Wahl ist – trotz seiner praktisch nicht vorhandenen Prognosekraft.

# %% [markdown]
# ## 4.2 Bekannte Limitationen
#
# 1. **Nahezu keine Prognosekraft (R² ≈ 0.000):** Niederschlag allein erklärt praktisch keine Varianz der individuellen Verspätungen. Ein sinnvoller Verspätungsprädiktor würde zusätzliche Merkmale benötigen: Wochentag, Feiertage, Tageszeit, Saison, Zugtyp sowie Echtzeit-Störungsdaten.
#
# 2. **Schwellenwert- statt Linear-Effekt:** Der Zusammenhang zwischen Niederschlag und Verspätung ist binär (trocken vs. nass) statt kontinuierlich (mehr Regen = proportional mehr Verspätung). Dadurch kann das Modell zwischen verschiedenen Wetterszenarien kaum differenzieren, ausser zwischen „Regen erwartet“ und „kein Regen“.
#
# 3. **Kategorie „Starkregen“ auf Bahnhofslevel unzuverlässig:** 198–752 Starkregen-Verbindungen pro Bahnhof sind zu wenig, um robuste Aussagen zu Extremwetter-Effekten zu treffen.ts.
#
# 4. **Nicht kontrollierte Störfaktoren:** Das beobachtete ρ = 0.074 könnte teilweise durch saisonale Effekte verzerrt sein (Herbst-/Wintermonate haben sowohl mehr Verspätungen als auch mehr Niederschlag). Ohne Fixed-Effects-Modelle lässt sich der kausale Effekt von Regen nicht isolieren.
#
# 5. **Bahnhofsnahe Wetterstationen:** MeteoSwiss Messstationen in Fluntern (Zürich),
#    Binningen (Basel), und Zollikofen (Bern) sind städtische Annäherungen. Wetterbedingungen entlang der gesamten Zugstrecke werden nicht erfasst.
#
# 6. **Negatives/Null-R² im Testset:** Ein R² nahe null bedeutet nicht, dass das Modell falsch ist, sondern dass es keine individuelle Prognosekraft besitzt. Es erfasst dennoch die Richtung des Durchschnittseffekts (Regen → leicht mehr Verspätung), kann aber einzelne Fahrten nicht zuverlässig vorhersagen.
#
# 7. **Untersuchungszeitraum**: Die 45 Monate (2022–2025) sind ein solider Zeitraum, schliessen jedoch die COVID-disruptiven Jahre 2020–2021 bewusst aus.

# %% [markdown]
# ## 4.3 Datengetriebene Entscheidung
#
# Das CPA-Framework erfordert, dass Erkenntnisse in eine konkrete Entscheidung überführt werden. Auf Basis der Evidenz dieser Studie lautet die empfohlene Entscheidung:
#
# ---
#
# **Entscheidung: Das Niederschlagsmodell wird als transparentes, disclaimer-orientiertes Verspätungsindikations-Tool eingesetzt — nicht als autoritativer Verspätungsrechner.**
#
# Die Analyse hat gezeigt, dass Niederschlag einen statistisch signifikanten, aber schwachen Effekt auf Verspätungen hat (Spearman ρ = 0.074, R² ≈ 0.000). Das auf 3’280’279 Verbindungen trainierte Random-Forest-Modell (RMSE = 6.610) erfasst diesen durchschnittlichen Trend und ist für eine einfache Anwendung geeignet — vorausgesetzt, seine Limitationen werden klar kommuniziert.
#
# **Phase 5 — Design der Webanwendung aus dieser Entscheidung abgeleitet:**
#
# Die Streamlit-App nimmt Bahnhof und geplante Ankunftszeit entgegen, ruft die MeteoSchweiz-7-Tage-Stundenprognose (mm/h) über die Open-Meteo-API ab, konvertiert diese in mm/10min (÷ 6) und speist den kontinuierlichen Wert in `model_all_data.pkl` ein, um eine prognostizierte Verspätung in Minuten zu berechnen. Zusätzlich zur numerischen Vorhersage wird eine vierstufige Niederschlagswarnung angezeigt:
#
# | Category | Hourly equivalent | Alert | Model input (mm/10min) |
# |---|---|---|---|
# | dry | 0 mm/h | 🟢 | 0.000 |
# | light | < 3 mm/h | 🟡 | < 0.500 |
# | moderate | 3–12 mm/h | 🟠 | 0.500–2.000 |
# | heavy | > 12 mm/h | 🔴 | > 2.000 |
#
# Ein manueller Eingabebereich erlaubt es, eine Niederschlagsintensität (mm/h) einzugeben und die prognostizierte Verspätung für alle drei Bahnhöfe gleichzeitig als Tabelle anzuzeigen.
#
# **Obligatorischer App-Hinweis (immer sichtbar):**
# > ⚠️ This prediction is based on a single-predictor model (R² ≈ 0.000).
# > Precipitation explains less than 0.25% of delay variance.
# > This tool indicates a general trend only — not a precise per-trip forecast.
#
# Dieser Ansatz ist datenbasiert und transparent. Er macht die Modellausgabe nutzbar, ohne die Grenzen der Vorhersagekraft zu verschleiern — genau das, was der CPA-Framework bei der Überführung von Daten in Entscheidungen verlangt.
#
# ---
#
# **Diese Entscheidung unterstützt NICHT:**
# - Betriebliche Anpassungen von SBB-Fahrplänen basierend auf Niederschlag allein
# - Exakte Verspätungsgarantien für einzelne Fahrten
# - Ersatz von SBB-Echtzeitdaten durch wetterbasierte Prognosen
#
# Für solche Anwendungen wären zusätzliche Features erforderlich (Wochentag, Zugtyp, Saison, Ereignisdaten etc.), wie in den Empfehlungen beschrieben.

# %% [markdown]
# ## 4.4 Vorschläge für weiterführende Arbeiten
#
# - **Zusätzliche Features:** Wochentag, Feiertage, Tageszeit, Saison, Zugtyp und Temperatur würden die Modellleistung deutlich über das aktuelle R² ≈ 0.000-Niveau hinaus verbessern. Selbst ein binäres `is_raining`-Feature
#   (0/1) würde den hier identifizierten Schwellenwerteffekt realistischer abbilden.
#
# - **Schwellenwerteffekt direkt modellieren:** Da der Effekt im Kern binär ist, könnte ein Klassifikationsmodell (trocken vs. nass → pünktlich vs. verspätet) geeigneter sein als eine Regression. Dadurch würde die Modellstruktur besser zum beobachteten Signal passen.
#
# - **Störfaktoren kontrollieren:** Die Einbeziehung von Monats- und Wochentags-Fixed-Effects würde helfen, den reinen Niederschlagseffekt von saisonalen Einflüssen zu trennen und so den Nettoeffekt besser zu isolieren.
#
# - **Zeitbereich erweitern oder verfeinern:** Die COVID-Jahre 2020–2021 wurden bewusst ausgeschlossen. Eine Erweiterung unter Verwendung eines COVID-Indikators könnte zusätzliche Informationen über atypische Betriebsbedingungen liefern.
#
# - **Wetter entlang der Strecke berücksichtigen:** Statt stationärer Stadtmessungen könnten interpolierte Niederschlagsdaten entlang der gesamten Zugroute (z. B. basierend auf MeteoSchweiz-Radargittern) verwendet werden, um lokale Wettereffekte besser abzubilden.

# %% [markdown]
# # 5. Quellenverzeichnis
#
# Marr, B. (2020). From data to decisions: A five-step approach to data-driven decision-making. https://moodle.bfh.ch/pluginfile.php/3730110/mod_resource/content/1/CPA-From-Data-to-Decisions-Guideline-Jan-2020.pdf
#
# MeteoSwiss (o. J.). Automatic precipitation stations. https://opendatadocs.meteoswiss.ch/a-data-groundbased/a2-automatic-precipitation-stations
#
# opentransportdata.swiss (o. J.). https://opentransportdata.swiss/de/cookbook/historic-and-statistics-cookbook/actual-data/
